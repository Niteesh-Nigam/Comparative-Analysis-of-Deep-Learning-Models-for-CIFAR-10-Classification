# %%
# Install necessary packages
# !pip install torch torchvision

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create project directory in Google Drive
import os
project_dir = '/content/drive/My Drive/MobileNetV2_CIFAR10'
os.makedirs(project_dir, exist_ok=True)

print("Project directory and necessary subdirectories created successfully.")
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.19.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Mounted at /content/drive
# Project directory and necessary subdirectories created successfully.

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# Data transformations for training and testing
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Load CIFAR-10 dataset
print('==> Preparing data..')
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
print('Data preparation complete.')
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43623489.83it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Data preparation complete.

# %%
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torch.nn.functional as F

class Block(nn.Module):
    '''expand + depthwise + pointwise'''
    def __init__(self, in_planes, out_planes, expansion, stride):
        super(Block, self).__init__()
        self.stride = stride

        planes = expansion * in_planes
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, groups=planes, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, out_planes, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn3 = nn.BatchNorm2d(out_planes)

        self.shortcut = nn.Sequential()
        if stride == 1 and in_planes != out_planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=1, padding=0, bias=False),
                nn.BatchNorm2d(out_planes),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = out + self.shortcut(x) if self.stride == 1 else out
        return out

class MobileNetV2(nn.Module):
    # (expansion, out_planes, num_blocks, stride)
    cfg = [(1,  16, 1, 1),
           (6,  24, 2, 1),  # NOTE: change stride 2 -> 1 for CIFAR10
           (6,  32, 3, 2),
           (6,  64, 4, 2),
           (6,  96, 3, 1),
           (6, 160, 3, 2),
           (6, 320, 1, 1)]

    def __init__(self, num_classes=10):
        super(MobileNetV2, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.layers = self._make_layers(in_planes=32)
        self.conv2 = nn.Conv2d(320, 1280, kernel_size=1, stride=1, padding=0, bias=False)
        self.bn2 = nn.BatchNorm2d(1280)
        self.linear = nn.Linear(1280, num_classes)

    def _make_layers(self, in_planes):
        layers = []
        for expansion, out_planes, num_blocks, stride in self.cfg:
            strides = [stride] + [1]*(num_blocks-1)
            for stride in strides:
                layers.append(Block(in_planes, out_planes, expansion, stride))
                in_planes = out_planes
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layers(out)
        out = F.relu(self.bn2(self.conv2(out)))
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# Initialize the model
print('==> Building model..')
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = MobileNetV2().to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True
print('Model built and moved to device.')
# Out:
# ==> Building model..
# Model built and moved to device.

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# Loss function, optimizer, and scheduler
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Lists to store metrics
train_loss_history = []
train_acc_history = []
test_loss_history = []
test_acc_history = []
f1_history = []
precision_history = []
recall_history = []

best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

def train(epoch):
    print(f'\nEpoch: {epoch}')
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    all_targets = []
    all_predictions = []

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        all_targets.extend(targets.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

    train_loss_history.append(train_loss / len(trainloader))
    train_acc_history.append(100. * correct / total)
    f1_history.append(f1_score(all_targets, all_predictions, average='macro'))
    precision_history.append(precision_score(all_targets, all_predictions, average='macro'))
    recall_history.append(recall_score(all_targets, all_predictions, average='macro'))

    print(f'Train Loss: {train_loss / len(trainloader):.3f} | Train Acc: {100. * correct / total:.3f}%')

def test(epoch):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    all_targets = []
    all_predictions = []

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            all_targets.extend(targets.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    test_loss_history.append(test_loss / len(testloader))
    test_acc_history.append(100. * correct / total)
    f1_history.append(f1_score(all_targets, all_predictions, average='macro'))
    precision_history.append(precision_score(all_targets, all_predictions, average='macro'))
    recall_history.append(recall_score(all_targets, all_predictions, average='macro'))

    acc = 100. * correct / total
    if acc > best_acc:
        print('Saving checkpoint..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        torch.save(state, f'{project_dir}/ckpt.pth')
        best_acc = acc

    print(f'Test Loss: {test_loss / len(testloader):.3f} | Test Acc: {acc:.3f}%')

# %%
print('==> Starting training..')
for epoch in range(start_epoch, start_epoch + 2):
    train(epoch)
    test(epoch)
    scheduler.step()

    # Save training history
    torch.save({
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'f1': f1_history,
        'precision': precision_history,
        'recall': recall_history,
    }, f'{project_dir}/history.pth')
print('Training complete.')
# Out:
# ==> Starting training..
#
# Epoch: 0
# Train Loss: 1.586 | Train Acc: 42.520%
# Saving checkpoint..
# Test Loss: 1.319 | Test Acc: 52.310%
#
# Epoch: 1
# Train Loss: 1.074 | Train Acc: 61.558%
# Saving checkpoint..
# Test Loss: 1.122 | Test Acc: 61.690%
#
# Epoch: 2
# Train Loss: 0.852 | Train Acc: 69.898%
# Saving checkpoint..
# Test Loss: 0.963 | Test Acc: 68.370%
#
# Epoch: 3
# Train Loss: 0.751 | Train Acc: 73.680%
# Saving checkpoint..
# Test Loss: 0.723 | Test Acc: 74.850%
#
# Epoch: 4
# Train Loss: 0.688 | Train Acc: 76.094%
# Test Loss: 0.732 | Test Acc: 74.710%
#
# Epoch: 5
# Train Loss: 0.648 | Train Acc: 77.496%
# Test Loss: 0.732 | Test Acc: 74.100%
#
# Epoch: 6
# Train Loss: 0.628 | Train Acc: 78.250%
# Test Loss: 0.868 | Test Acc: 71.220%
#
# Epoch: 7
# Train Loss: 0.614 | Train Acc: 78.828%
# Test Loss: 0.808 | Test Acc: 72.840%
#
# Epoch: 8
# Train Loss: 0.601 | Train Acc: 79.300%
# Saving checkpoint..
# Test Loss: 0.714 | Test Acc: 75.290%
#
# Epoch: 9
# Train Loss: 0.603 | Train Acc: 79.280%
# Saving checkpoint..
# Test Loss: 0.649 | Test Acc: 77.860%
#
# Epoch: 10
# Train Loss: 0.593 | Train Acc: 79.708%
# Test Loss: 0.687 | Test Acc: 77.100%
#
# Epoch: 11
# Train Loss: 0.595 | Train Acc: 79.364%
# Test Loss: 0.675 | Test Acc: 77.210%
#
# Epoch: 12
# Train Loss: 0.598 | Train Acc: 79.308%
# Test Loss: 0.765 | Test Acc: 74.750%
#
# Epoch: 13
# Train Loss: 0.587 | Train Acc: 79.694%
# Test Loss: 0.661 | Test Acc: 77.100%
#
# Epoch: 14
# Train Loss: 0.583 | Train Acc: 80.162%
# Test Loss: 0.718 | Test Acc: 75.340%
#
# Epoch: 15
# Train Loss: 0.587 | Train Acc: 79.888%
# Test Loss: 0.703 | Test Acc: 76.690%
#
# Epoch: 16
# Train Loss: 0.583 | Train Acc: 80.124%
# Saving checkpoint..
# Test Loss: 0.628 | Test Acc: 78.460%
#
# Epoch: 17
# Train Loss: 0.579 | Train Acc: 80.116%
# Test Loss: 0.786 | Test Acc: 74.160%
#
# Epoch: 18
# Train Loss: 0.580 | Train Acc: 80.204%
# Test Loss: 0.814 | Test Acc: 73.470%
#
# Epoch: 19
# Train Loss: 0.575 | Train Acc: 80.458%
# Test Loss: 0.871 | Test Acc: 72.400%
#
# Epoch: 20
# Train Loss: 0.576 | Train Acc: 80.178%
# Test Loss: 0.685 | Test Acc: 76.920%
#
# Epoch: 21
# Train Loss: 0.573 | Train Acc: 80.386%
# Test Loss: 0.680 | Test Acc: 77.190%
#
# Epoch: 22
# Train Loss: 0.574 | Train Acc: 80.264%
# Test Loss: 0.702 | Test Acc: 75.980%
#
# Epoch: 23
# Train Loss: 0.572 | Train Acc: 80.384%
# Test Loss: 0.706 | Test Acc: 76.980%
#
# Epoch: 24
# Train Loss: 0.569 | Train Acc: 80.376%
# Saving checkpoint..
# Test Loss: 0.630 | Test Acc: 78.590%
#
# Epoch: 25
# Train Loss: 0.572 | Train Acc: 80.352%
# Test Loss: 0.722 | Test Acc: 76.280%
#
# Epoch: 26
# Train Loss: 0.571 | Train Acc: 80.332%
# Test Loss: 0.692 | Test Acc: 76.210%
#
# Epoch: 27
# Train Loss: 0.563 | Train Acc: 80.880%
# Saving checkpoint..
# Test Loss: 0.585 | Test Acc: 80.550%
#
# Epoch: 28
# Train Loss: 0.561 | Train Acc: 80.730%
# Test Loss: 0.758 | Test Acc: 73.650%
#
# Epoch: 29
# Train Loss: 0.568 | Train Acc: 80.424%
# Test Loss: 0.761 | Test Acc: 75.250%
#
# Epoch: 30
# Train Loss: 0.565 | Train Acc: 80.594%
# Test Loss: 0.680 | Test Acc: 77.460%
#
# Epoch: 31
# Train Loss: 0.557 | Train Acc: 80.780%
# Test Loss: 0.656 | Test Acc: 77.880%
#
# Epoch: 32
# Train Loss: 0.555 | Train Acc: 81.000%
# Test Loss: 0.596 | Test Acc: 79.990%
#
# Epoch: 33
# Train Loss: 0.561 | Train Acc: 80.652%
# Test Loss: 0.659 | Test Acc: 77.610%
#
# Epoch: 34
# Train Loss: 0.552 | Train Acc: 81.160%
# Test Loss: 0.595 | Test Acc: 79.870%
#
# Epoch: 35
# Train Loss: 0.557 | Train Acc: 80.748%
# Test Loss: 0.640 | Test Acc: 77.860%
#
# Epoch: 36
# Train Loss: 0.556 | Train Acc: 81.054%
# Test Loss: 0.702 | Test Acc: 75.600%
#
# Epoch: 37
# Train Loss: 0.552 | Train Acc: 80.884%
# Test Loss: 0.645 | Test Acc: 78.350%
#
# Epoch: 38
# Train Loss: 0.542 | Train Acc: 81.378%
# Test Loss: 0.634 | Test Acc: 78.600%
#
# Epoch: 39
# Train Loss: 0.552 | Train Acc: 80.974%
# Test Loss: 0.615 | Test Acc: 78.750%
#
# Epoch: 40
# Train Loss: 0.549 | Train Acc: 81.306%
# Test Loss: 0.629 | Test Acc: 78.960%
#
# Epoch: 41
# Train Loss: 0.544 | Train Acc: 81.312%
# Test Loss: 0.648 | Test Acc: 78.150%
#
# Epoch: 42
# Train Loss: 0.552 | Train Acc: 81.050%
# Test Loss: 0.703 | Test Acc: 76.480%
#
# Epoch: 43
# Train Loss: 0.544 | Train Acc: 81.380%
# Test Loss: 0.596 | Test Acc: 79.400%
#
# Epoch: 44
# Train Loss: 0.546 | Train Acc: 81.314%
# Test Loss: 0.606 | Test Acc: 79.360%
#
# Epoch: 45
# Train Loss: 0.539 | Train Acc: 81.426%
# Test Loss: 0.590 | Test Acc: 80.010%
#
# Epoch: 46
# Train Loss: 0.540 | Train Acc: 81.596%
# Test Loss: 0.606 | Test Acc: 79.320%
#
# Epoch: 47
# Train Loss: 0.538 | Train Acc: 81.562%
# Test Loss: 0.678 | Test Acc: 77.350%
#
# Epoch: 48
# Train Loss: 0.539 | Train Acc: 81.458%
# Test Loss: 0.788 | Test Acc: 72.980%
#
# Epoch: 49
# Train Loss: 0.528 | Train Acc: 81.864%
# Test Loss: 0.629 | Test Acc: 78.870%
#
# Epoch: 50
# Train Loss: 0.531 | Train Acc: 81.766%
# Test Loss: 0.615 | Test Acc: 78.540%
#
# Epoch: 51
# Train Loss: 0.527 | Train Acc: 81.842%
# Test Loss: 0.811 | Test Acc: 74.120%
#
# Epoch: 52
# Train Loss: 0.539 | Train Acc: 81.600%
# Test Loss: 1.071 | Test Acc: 67.690%
#
# Epoch: 53
# Train Loss: 0.535 | Train Acc: 81.594%
# Test Loss: 0.597 | Test Acc: 79.370%
#
# Epoch: 54
# Train Loss: 0.531 | Train Acc: 81.834%
# Saving checkpoint..
# Test Loss: 0.553 | Test Acc: 80.860%
#
# Epoch: 55
# Train Loss: 0.528 | Train Acc: 81.976%
# Test Loss: 0.577 | Test Acc: 80.230%
#
# Epoch: 56
# Train Loss: 0.532 | Train Acc: 81.674%
# Test Loss: 0.700 | Test Acc: 75.930%
#
# Epoch: 57
# Train Loss: 0.533 | Train Acc: 81.700%
# Test Loss: 0.594 | Test Acc: 80.090%
#
# Epoch: 58
# Train Loss: 0.520 | Train Acc: 82.116%
# Test Loss: 0.840 | Test Acc: 73.250%
#
# Epoch: 59
# Train Loss: 0.531 | Train Acc: 81.868%
# Test Loss: 1.178 | Test Acc: 64.350%
#
# Epoch: 60
# Train Loss: 0.526 | Train Acc: 81.880%
# Test Loss: 0.704 | Test Acc: 77.590%
#
# Epoch: 61
# Train Loss: 0.525 | Train Acc: 82.058%
# Saving checkpoint..
# Test Loss: 0.553 | Test Acc: 81.330%
#
# Epoch: 62
# Train Loss: 0.517 | Train Acc: 82.374%
# Test Loss: 0.644 | Test Acc: 78.470%
#
# Epoch: 63
# Train Loss: 0.522 | Train Acc: 82.116%
# Saving checkpoint..
# Test Loss: 0.530 | Test Acc: 81.930%
#
# Epoch: 64
# Train Loss: 0.518 | Train Acc: 82.174%
# Test Loss: 0.682 | Test Acc: 76.650%
#
# Epoch: 65
# Train Loss: 0.516 | Train Acc: 82.436%
# Test Loss: 0.707 | Test Acc: 76.850%
#
# Epoch: 66
# Train Loss: 0.514 | Train Acc: 82.444%
# Test Loss: 0.744 | Test Acc: 74.980%
#
# Epoch: 67
# Train Loss: 0.517 | Train Acc: 82.332%
# Test Loss: 0.701 | Test Acc: 76.390%
#
# Epoch: 68
# Train Loss: 0.508 | Train Acc: 82.558%
# Test Loss: 0.563 | Test Acc: 80.970%
#
# Epoch: 69
# Train Loss: 0.512 | Train Acc: 82.514%
# Test Loss: 0.748 | Test Acc: 75.030%
#
# Epoch: 70
# Train Loss: 0.512 | Train Acc: 82.460%
# Test Loss: 0.610 | Test Acc: 79.160%
#
# Epoch: 71
# Train Loss: 0.505 | Train Acc: 82.552%
# Test Loss: 0.591 | Test Acc: 79.990%
#
# Epoch: 72
# Train Loss: 0.511 | Train Acc: 82.448%
# Test Loss: 0.578 | Test Acc: 80.380%
#
# Epoch: 73
# Train Loss: 0.499 | Train Acc: 82.888%
# Test Loss: 0.829 | Test Acc: 72.220%
#
# Epoch: 74
# Train Loss: 0.502 | Train Acc: 82.582%
# Test Loss: 0.632 | Test Acc: 78.600%
#
# Epoch: 75
# Train Loss: 0.497 | Train Acc: 83.038%
# Test Loss: 0.639 | Test Acc: 77.840%
#
# Epoch: 76
# Train Loss: 0.496 | Train Acc: 82.848%
# Saving checkpoint..
# Test Loss: 0.532 | Test Acc: 82.320%
#
# Epoch: 77
# Train Loss: 0.498 | Train Acc: 82.912%
# Test Loss: 0.559 | Test Acc: 81.090%
#
# Epoch: 78
# Train Loss: 0.495 | Train Acc: 83.028%
# Test Loss: 0.603 | Test Acc: 79.280%
#
# Epoch: 79
# Train Loss: 0.492 | Train Acc: 83.104%
# Test Loss: 0.605 | Test Acc: 79.630%
#
# Epoch: 80
# Train Loss: 0.497 | Train Acc: 82.962%
# Test Loss: 0.525 | Test Acc: 81.700%
#
# Epoch: 81
# Train Loss: 0.485 | Train Acc: 83.408%
# Test Loss: 0.626 | Test Acc: 78.930%
#
# Epoch: 82
# Train Loss: 0.490 | Train Acc: 83.138%
# Test Loss: 0.515 | Test Acc: 82.290%
#
# Epoch: 83
# Train Loss: 0.482 | Train Acc: 83.380%
# Test Loss: 0.660 | Test Acc: 77.730%
#
# Epoch: 84
# Train Loss: 0.480 | Train Acc: 83.652%
# Test Loss: 0.568 | Test Acc: 80.630%
#
# Epoch: 85
# Train Loss: 0.485 | Train Acc: 83.206%
# Test Loss: 0.540 | Test Acc: 81.430%
#
# Epoch: 86
# Train Loss: 0.472 | Train Acc: 83.848%
# Test Loss: 0.578 | Test Acc: 80.160%
#
# Epoch: 87
# Train Loss: 0.476 | Train Acc: 83.542%
# Test Loss: 0.549 | Test Acc: 81.590%
#
# Epoch: 88
# Train Loss: 0.467 | Train Acc: 84.040%
# Test Loss: 0.631 | Test Acc: 79.550%
#
# Epoch: 89
# Train Loss: 0.470 | Train Acc: 83.690%
# Test Loss: 0.524 | Test Acc: 82.070%
#
# Epoch: 90
# Train Loss: 0.467 | Train Acc: 83.942%
# Test Loss: 0.760 | Test Acc: 74.380%
#
# Epoch: 91
# Train Loss: 0.464 | Train Acc: 84.032%
# Test Loss: 0.810 | Test Acc: 73.860%
#
# Epoch: 92
# Train Loss: 0.460 | Train Acc: 84.268%
# Saving checkpoint..
# Test Loss: 0.471 | Test Acc: 83.810%
#
# Epoch: 93
# Train Loss: 0.463 | Train Acc: 83.958%
# Test Loss: 0.640 | Test Acc: 78.370%
#
# Epoch: 94
# Train Loss: 0.463 | Train Acc: 84.164%
# Test Loss: 0.515 | Test Acc: 82.830%
#
# Epoch: 95
# Train Loss: 0.452 | Train Acc: 84.420%
# Test Loss: 0.607 | Test Acc: 79.690%
#
# Epoch: 96
# Train Loss: 0.452 | Train Acc: 84.576%
# Test Loss: 0.613 | Test Acc: 80.090%
#
# Epoch: 97
# Train Loss: 0.453 | Train Acc: 84.410%
# Test Loss: 0.534 | Test Acc: 82.060%
#
# Epoch: 98
# Train Loss: 0.448 | Train Acc: 84.620%
# Test Loss: 0.526 | Test Acc: 82.400%
#
# Epoch: 99
# Train Loss: 0.448 | Train Acc: 84.800%
# Test Loss: 0.518 | Test Acc: 82.400%
#
# Epoch: 100
# Train Loss: 0.441 | Train Acc: 84.710%
# Test Loss: 0.599 | Test Acc: 80.050%
#
# Epoch: 101
# Train Loss: 0.441 | Train Acc: 84.890%
# Test Loss: 0.491 | Test Acc: 83.510%
#
# Epoch: 102
# Train Loss: 0.437 | Train Acc: 84.910%
# Test Loss: 0.496 | Test Acc: 82.670%
#
# Epoch: 103
# Train Loss: 0.437 | Train Acc: 84.936%
# Test Loss: 0.536 | Test Acc: 81.600%
#
# Epoch: 104
# Train Loss: 0.433 | Train Acc: 85.098%
# Saving checkpoint..
# Test Loss: 0.468 | Test Acc: 84.260%
#
# Epoch: 105
# Train Loss: 0.431 | Train Acc: 85.184%
# Test Loss: 0.511 | Test Acc: 83.080%
#
# Epoch: 106
# Train Loss: 0.426 | Train Acc: 85.210%
# Test Loss: 0.617 | Test Acc: 79.350%
#
# Epoch: 107
# Train Loss: 0.425 | Train Acc: 85.484%
# Test Loss: 0.549 | Test Acc: 81.530%
#
# Epoch: 108
# Train Loss: 0.422 | Train Acc: 85.568%
# Saving checkpoint..
# Test Loss: 0.444 | Test Acc: 84.360%
#
# Epoch: 109
# Train Loss: 0.423 | Train Acc: 85.602%
# Saving checkpoint..
# Test Loss: 0.455 | Test Acc: 84.960%
#
# Epoch: 110
# Train Loss: 0.411 | Train Acc: 85.930%
# Test Loss: 0.455 | Test Acc: 84.710%
#
# Epoch: 111
# Train Loss: 0.416 | Train Acc: 85.714%
# Test Loss: 0.538 | Test Acc: 82.170%
#
# Epoch: 112
# Train Loss: 0.411 | Train Acc: 86.020%
# Test Loss: 0.450 | Test Acc: 84.760%
#
# Epoch: 113
# Train Loss: 0.407 | Train Acc: 85.918%
# Test Loss: 0.482 | Test Acc: 83.850%
#
# Epoch: 114
# Train Loss: 0.396 | Train Acc: 86.492%
# Test Loss: 0.578 | Test Acc: 80.410%
#
# Epoch: 115
# Train Loss: 0.399 | Train Acc: 86.308%
# Test Loss: 0.487 | Test Acc: 83.460%
#
# Epoch: 116
# Train Loss: 0.399 | Train Acc: 86.376%
# Saving checkpoint..
# Test Loss: 0.449 | Test Acc: 85.070%
#
# Epoch: 117
# Train Loss: 0.398 | Train Acc: 86.442%
# Saving checkpoint..
# Test Loss: 0.434 | Test Acc: 85.340%
#
# Epoch: 118
# Train Loss: 0.394 | Train Acc: 86.428%
# Test Loss: 0.495 | Test Acc: 83.740%
#
# Epoch: 119
# Train Loss: 0.390 | Train Acc: 86.634%
# Saving checkpoint..
# Test Loss: 0.438 | Test Acc: 85.460%
#
# Epoch: 120
# Train Loss: 0.385 | Train Acc: 86.746%
# Test Loss: 0.463 | Test Acc: 84.170%
#
# Epoch: 121
# Train Loss: 0.382 | Train Acc: 86.956%
# Test Loss: 0.454 | Test Acc: 84.430%
#
# Epoch: 122
# Train Loss: 0.381 | Train Acc: 86.954%
# Test Loss: 0.443 | Test Acc: 85.310%
#
# Epoch: 123
# Train Loss: 0.374 | Train Acc: 87.070%
# Test Loss: 0.445 | Test Acc: 84.660%
#
# Epoch: 124
# Train Loss: 0.368 | Train Acc: 87.314%
# Test Loss: 0.476 | Test Acc: 84.290%
#
# Epoch: 125
# Train Loss: 0.367 | Train Acc: 87.328%
# Saving checkpoint..
# Test Loss: 0.390 | Test Acc: 86.380%
#
# Epoch: 126
# Train Loss: 0.363 | Train Acc: 87.328%
# Test Loss: 0.426 | Test Acc: 85.560%
#
# Epoch: 127
# Train Loss: 0.357 | Train Acc: 87.606%
# Test Loss: 0.404 | Test Acc: 86.120%
#
# Epoch: 128
# Train Loss: 0.350 | Train Acc: 88.050%
# Test Loss: 0.407 | Test Acc: 86.260%
#
# Epoch: 129
# Train Loss: 0.347 | Train Acc: 88.190%
# Test Loss: 0.458 | Test Acc: 84.540%
#
# Epoch: 130
# Train Loss: 0.348 | Train Acc: 87.996%
# Test Loss: 0.419 | Test Acc: 85.850%
#
# Epoch: 131
# Train Loss: 0.343 | Train Acc: 88.276%
# Test Loss: 0.441 | Test Acc: 85.240%
#
# Epoch: 132
# Train Loss: 0.341 | Train Acc: 88.258%
# Saving checkpoint..
# Test Loss: 0.385 | Test Acc: 87.080%
#
# Epoch: 133
# Train Loss: 0.335 | Train Acc: 88.416%
# Test Loss: 0.431 | Test Acc: 85.780%
#
# Epoch: 134
# Train Loss: 0.333 | Train Acc: 88.514%
# Test Loss: 0.407 | Test Acc: 86.320%
#
# Epoch: 135
# Train Loss: 0.321 | Train Acc: 88.898%
# Test Loss: 0.385 | Test Acc: 86.990%
#
# Epoch: 136
# Train Loss: 0.320 | Train Acc: 88.916%
# Test Loss: 0.404 | Test Acc: 86.440%
#
# Epoch: 137
# Train Loss: 0.319 | Train Acc: 89.078%
# Test Loss: 0.391 | Test Acc: 86.930%
#
# Epoch: 138
# Train Loss: 0.318 | Train Acc: 88.972%
# Test Loss: 0.403 | Test Acc: 86.570%
#
# Epoch: 139
# Train Loss: 0.314 | Train Acc: 89.260%
# Saving checkpoint..
# Test Loss: 0.362 | Test Acc: 87.650%
#
# Epoch: 140
# Train Loss: 0.304 | Train Acc: 89.566%
# Saving checkpoint..
# Test Loss: 0.371 | Test Acc: 87.820%
#
# Epoch: 141
# Train Loss: 0.295 | Train Acc: 89.758%
# Test Loss: 0.371 | Test Acc: 87.750%
#
# Epoch: 142
# Train Loss: 0.298 | Train Acc: 89.612%
# Test Loss: 0.407 | Test Acc: 86.370%
#
# Epoch: 143
# Train Loss: 0.288 | Train Acc: 89.906%
# Test Loss: 0.370 | Test Acc: 87.580%
#
# Epoch: 144
# Train Loss: 0.288 | Train Acc: 89.930%
# Saving checkpoint..
# Test Loss: 0.351 | Test Acc: 87.970%
#
# Epoch: 145
# Train Loss: 0.282 | Train Acc: 90.300%
# Saving checkpoint..
# Test Loss: 0.361 | Test Acc: 88.060%
#
# Epoch: 146
# Train Loss: 0.275 | Train Acc: 90.432%
# Saving checkpoint..
# Test Loss: 0.347 | Test Acc: 88.470%
#
# Epoch: 147
# Train Loss: 0.272 | Train Acc: 90.648%
# Test Loss: 0.359 | Test Acc: 87.910%
#
# Epoch: 148
# Train Loss: 0.267 | Train Acc: 90.850%
# Test Loss: 0.380 | Test Acc: 87.280%
#
# Epoch: 149
# Train Loss: 0.264 | Train Acc: 90.794%
# Test Loss: 0.365 | Test Acc: 87.900%
#
# Epoch: 150
# Train Loss: 0.257 | Train Acc: 91.138%
# Saving checkpoint..
# Test Loss: 0.343 | Test Acc: 88.490%
#
# Epoch: 151
# Train Loss: 0.255 | Train Acc: 91.122%
# Saving checkpoint..
# Test Loss: 0.327 | Test Acc: 88.930%
#
# Epoch: 152
# Train Loss: 0.250 | Train Acc: 91.352%
# Saving checkpoint..
# Test Loss: 0.315 | Test Acc: 89.610%
#
# Epoch: 153
# Train Loss: 0.242 | Train Acc: 91.696%
# Saving checkpoint..
# Test Loss: 0.305 | Test Acc: 89.650%
#
# Epoch: 154
# Train Loss: 0.240 | Train Acc: 91.740%
# Test Loss: 0.312 | Test Acc: 89.400%
#
# Epoch: 155
# Train Loss: 0.234 | Train Acc: 91.852%
# Test Loss: 0.335 | Test Acc: 88.850%
#
# Epoch: 156
# Train Loss: 0.233 | Train Acc: 91.886%
# Test Loss: 0.327 | Test Acc: 89.110%
#
# Epoch: 157
# Train Loss: 0.227 | Train Acc: 92.126%
# Saving checkpoint..
# Test Loss: 0.299 | Test Acc: 90.010%
#
# Epoch: 158
# Train Loss: 0.217 | Train Acc: 92.496%
# Test Loss: 0.320 | Test Acc: 89.400%
#
# Epoch: 159
# Train Loss: 0.219 | Train Acc: 92.472%
# Saving checkpoint..
# Test Loss: 0.296 | Test Acc: 90.220%
#
# Epoch: 160
# Train Loss: 0.209 | Train Acc: 92.778%
# Saving checkpoint..
# Test Loss: 0.298 | Test Acc: 90.250%
#
# Epoch: 161
# Train Loss: 0.206 | Train Acc: 92.808%
# Test Loss: 0.306 | Test Acc: 90.000%
#
# Epoch: 162
# Train Loss: 0.199 | Train Acc: 93.164%
# Test Loss: 0.300 | Test Acc: 90.070%
#
# Epoch: 163
# Train Loss: 0.189 | Train Acc: 93.470%
# Saving checkpoint..
# Test Loss: 0.289 | Test Acc: 90.360%
#
# Epoch: 164
# Train Loss: 0.187 | Train Acc: 93.488%
# Test Loss: 0.342 | Test Acc: 89.000%
#
# Epoch: 165
# Train Loss: 0.180 | Train Acc: 93.738%
# Test Loss: 0.291 | Test Acc: 90.260%
#
# Epoch: 166
# Train Loss: 0.179 | Train Acc: 93.974%
# Saving checkpoint..
# Test Loss: 0.295 | Test Acc: 90.610%
#
# Epoch: 167
# Train Loss: 0.172 | Train Acc: 94.016%
# Saving checkpoint..
# Test Loss: 0.282 | Test Acc: 90.960%
#
# Epoch: 168
# Train Loss: 0.169 | Train Acc: 94.278%
# Test Loss: 0.274 | Test Acc: 90.960%
#
# Epoch: 169
# Train Loss: 0.159 | Train Acc: 94.478%
# Saving checkpoint..
# Test Loss: 0.271 | Test Acc: 91.340%
#
# Epoch: 170
# Train Loss: 0.151 | Train Acc: 94.824%
# Test Loss: 0.286 | Test Acc: 90.900%
#
# Epoch: 171
# Train Loss: 0.147 | Train Acc: 94.918%
# Test Loss: 0.291 | Test Acc: 90.600%
#
# Epoch: 172
# Train Loss: 0.144 | Train Acc: 95.152%
# Saving checkpoint..
# Test Loss: 0.273 | Test Acc: 91.430%
#
# Epoch: 173
# Train Loss: 0.137 | Train Acc: 95.250%
# Saving checkpoint..
# Test Loss: 0.272 | Test Acc: 91.700%
#
# Epoch: 174
# Train Loss: 0.132 | Train Acc: 95.518%
# Test Loss: 0.270 | Test Acc: 91.300%
#
# Epoch: 175
# Train Loss: 0.129 | Train Acc: 95.540%
# Test Loss: 0.271 | Test Acc: 91.560%
#
# Epoch: 176
# Train Loss: 0.120 | Train Acc: 95.932%
# Test Loss: 0.265 | Test Acc: 91.680%
#
# Epoch: 177
# Train Loss: 0.121 | Train Acc: 95.852%
# Test Loss: 0.270 | Test Acc: 91.560%
#
# Epoch: 178
# Train Loss: 0.110 | Train Acc: 96.186%
# Test Loss: 0.262 | Test Acc: 91.680%
#
# Epoch: 179
# Train Loss: 0.108 | Train Acc: 96.238%
# Test Loss: 0.266 | Test Acc: 91.610%
#
# Epoch: 180
# Train Loss: 0.101 | Train Acc: 96.520%
# Saving checkpoint..
# Test Loss: 0.256 | Test Acc: 92.200%
#
# Epoch: 181
# Train Loss: 0.097 | Train Acc: 96.664%
# Test Loss: 0.265 | Test Acc: 91.740%
#
# Epoch: 182
# Train Loss: 0.093 | Train Acc: 96.866%
# Test Loss: 0.259 | Test Acc: 92.020%
#
# Epoch: 183
# Train Loss: 0.088 | Train Acc: 97.056%
# Test Loss: 0.265 | Test Acc: 92.030%
#
# Epoch: 184
# Train Loss: 0.083 | Train Acc: 97.238%
# Test Loss: 0.264 | Test Acc: 91.950%
#
# Epoch: 185
# Train Loss: 0.081 | Train Acc: 97.354%
# Saving checkpoint..
# Test Loss: 0.256 | Test Acc: 92.290%
#
# Epoch: 186
# Train Loss: 0.078 | Train Acc: 97.470%
# Saving checkpoint..
# Test Loss: 0.254 | Test Acc: 92.320%
#
# Epoch: 187
# Train Loss: 0.077 | Train Acc: 97.508%
# Test Loss: 0.261 | Test Acc: 92.170%
#
# Epoch: 188
# Train Loss: 0.070 | Train Acc: 97.712%
# Test Loss: 0.257 | Test Acc: 92.150%
#
# Epoch: 189
# Train Loss: 0.070 | Train Acc: 97.700%
# Test Loss: 0.257 | Test Acc: 92.280%
#
# Epoch: 190
# Train Loss: 0.069 | Train Acc: 97.806%
# Saving checkpoint..
# Test Loss: 0.256 | Test Acc: 92.350%
#
# Epoch: 191
# Train Loss: 0.064 | Train Acc: 98.000%
# Test Loss: 0.257 | Test Acc: 92.240%
#
# Epoch: 192
# Train Loss: 0.064 | Train Acc: 97.980%
# Test Loss: 0.257 | Test Acc: 92.310%
#
# Epoch: 193
# Train Loss: 0.062 | Train Acc: 98.026%
# Test Loss: 0.260 | Test Acc: 92.320%
#
# Epoch: 194
# Train Loss: 0.061 | Train Acc: 98.108%
# Test Loss: 0.258 | Test Acc: 92.290%
#
# Epoch: 195
# Train Loss: 0.061 | Train Acc: 98.138%
# Saving checkpoint..
# Test Loss: 0.257 | Test Acc: 92.380%
#
# Epoch: 196
# Train Loss: 0.061 | Train Acc: 98.092%
# Test Loss: 0.258 | Test Acc: 92.260%
#
# Epoch: 197
# Train Loss: 0.060 | Train Acc: 98.160%
# Test Loss: 0.259 | Test Acc: 92.280%
#
# Epoch: 198
# Train Loss: 0.060 | Train Acc: 98.076%
# Test Loss: 0.259 | Test Acc: 92.300%
#
# Epoch: 199
# Train Loss: 0.059 | Train Acc: 98.120%
# Test Loss: 0.256 | Test Acc: 92.380%
# Training complete.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Load history
history = torch.load(f'{project_dir}/history.pth')

def plot_history():
    # Determine the minimum length of the history lists to avoid dimension mismatch
    min_length = min(len(history['train_loss']), len(history['test_loss']),
                     len(history['train_acc']), len(history['test_acc']),
                     len(history['f1']), len(history['precision']), len(history['recall']))

    epochs = range(1, min_length + 1)

    plt.figure(figsize=(16, 12))

    plt.subplot(2, 2, 1)
    plt.plot(epochs, history['train_loss'][:min_length], label='Train Loss')
    plt.plot(epochs, history['test_loss'][:min_length], label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss History')
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(epochs, history['train_acc'][:min_length], label='Train Accuracy')
    plt.plot(epochs, history['test_acc'][:min_length], label='Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy History')
    plt.legend()

    plt.subplot(2, 2, 3)
    plt.plot(epochs, history['f1'][:min_length], label='F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.title('F1 Score History')
    plt.legend()

    plt.subplot(2, 2, 4)
    plt.plot(epochs, history['precision'][:min_length], label='Precision')
    plt.plot(epochs, history['recall'][:min_length], label='Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Score')
    plt.title('Precision and Recall History')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'{project_dir}/training_plots.png')
    plt.show()

plot_history()

# %%
def plot_confusion_matrix():
    # Confusion matrix on the test set
    net.eval()
    all_targets = []
    all_predictions = []

    with torch.no_grad():
        for inputs, targets in testloader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            _, predicted = outputs.max(1)
            all_targets.extend(targets.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    cm = confusion_matrix(all_targets, all_predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.savefig(f'{project_dir}/confusion_matrix.png')
    plt.show()

plot_confusion_matrix()

# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Define the project directory (extracted from the provided file)
project_dir = '/content/drive/My Drive/MobileNetV2_CIFAR10'
ckpt_path = f'{project_dir}/ckpt.pth'
history_path = f'{project_dir}/history.pth'

# Load functions
def load_checkpoint(path):
    checkpoint = torch.load(path, map_location=torch.device('cpu'))
    return checkpoint

def load_history(path):
    history = torch.load(path, map_location=torch.device('cpu'))
    return history

# Print functions
def print_checkpoint(checkpoint):
    print("Checkpoint Contents:")
    print(f"Epoch: {checkpoint['epoch']}")
    print(f"Accuracy: {checkpoint['acc']}")
    print("Model State Dict Keys:")
    print(checkpoint['net'].keys())

def print_history(history):
    print("History Contents:")
    print(history.keys())
    for key, value in history.items():
        print(f"{key}: {value[:5]}...")  # Print first 5 entries for brevity

# Plotting functions
def plot_history(history):
    min_length = min(len(history['train_loss']), len(history['test_loss']),
                     len(history['train_acc']), len(history['test_acc']),
                     len(history['f1']), len(history['precision']), len(history['recall']))

    epochs = range(1, min_length + 1)

    # Plot Loss
    plt.figure(figsize=(14, 10))

    plt.subplot(2, 2, 1)
    plt.plot(epochs, history['train_loss'][:min_length], label='Train Loss')
    plt.plot(epochs, history['test_loss'][:min_length], label='Test Loss')
    plt.title('Loss History')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(2, 2, 2)
    plt.plot(epochs, history['train_acc'][:min_length], label='Train Accuracy')
    plt.plot(epochs, history['test_acc'][:min_length], label='Test Accuracy')
    plt.title('Accuracy History')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot F1 Score
    plt.subplot(2, 2, 3)
    plt.plot(epochs, history['f1'][:min_length], label='F1 Score')
    plt.title('F1 Score History')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    # Plot Precision and Recall
    plt.subplot(2, 2, 4)
    plt.plot(epochs, history['precision'][:min_length], label='Precision')
    plt.plot(epochs, history['recall'][:min_length], label='Recall')
    plt.title('Precision and Recall History')
    plt.xlabel('Epochs')
    plt.ylabel('Score')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'{project_dir}/training_plots.png')
    plt.show()

def main():
    # Load and print checkpoint
    checkpoint = load_checkpoint(ckpt_path)
    print_checkpoint(checkpoint)

    # Load and print history
    history = load_history(history_path)
    print_history(history)

    # Plot metrics
    plot_history(history)

    # Compute and print confusion matrix for the best/latest epoch
    # Assuming the last entry contains the targets and predictions
    y_true = history.get('targets', [None])[-1]
    y_pred = history.get('predictions', [None])[-1]
    if y_true is not None and y_pred is not None:
        cm = confusion_matrix(y_true, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot(cmap=plt.cm.Blues)
        plt.title('Confusion Matrix')
        plt.show()

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-8-af9b4c5c0f2e>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=torch.device('cpu'))
# <ipython-input-8-af9b4c5c0f2e>:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   history = torch.load(path, map_location=torch.device('cpu'))
# Checkpoint Contents:
# Epoch: 195
# Accuracy: 92.38
# Model State Dict Keys:
# odict_keys(['module.conv1.weight', 'module.bn1.weight', 'module.bn1.bias', 'module.bn1.running_mean', 'module.bn1.running_var', 'module.bn1.num_batches_tracked', 'module.layers.0.conv1.weight', 'module.layers.0.bn1.weight', 'module.layers.0.bn1.bias', 'module.layers.0.bn1.running_mean', 'module.layers.0.bn1.running_var', 'module.layers.0.bn1.num_batches_tracked', 'module.layers.0.conv2.weight', 'module.layers.0.bn2.weight', 'module.layers.0.bn2.bias', 'module.layers.0.bn2.running_mean', 'module.layers.0.bn2.running_var', 'module.layers.0.bn2.num_batches_tracked', 'module.layers.0.conv3.weight', 'module.layers.0.bn3.weight', 'module.layers.0.bn3.bias', 'module.layers.0.bn3.running_mean', 'module.layers.0.bn3.running_var', 'module.layers.0.bn3.num_batches_tracked', 'module.layers.0.shortcut.0.weight', 'module.layers.0.shortcut.1.weight', 'module.layers.0.shortcut.1.bias', 'module.layers.0.shortcut.1.running_mean', 'module.layers.0.shortcut.1.running_var', 'module.layers.0.shortcut.1.num_batches_tracked', 'module.layers.1.conv1.weight', 'module.layers.1.bn1.weight', 'module.layers.1.bn1.bias', 'module.layers.1.bn1.running_mean', 'module.layers.1.bn1.running_var', 'module.layers.1.bn1.num_batches_tracked', 'module.layers.1.conv2.weight', 'module.layers.1.bn2.weight', 'module.layers.1.bn2.bias', 'module.layers.1.bn2.running_mean', 'module.layers.1.bn2.running_var', 'module.layers.1.bn2.num_batches_tracked', 'module.layers.1.conv3.weight', 'module.layers.1.bn3.weight', 'module.layers.1.bn3.bias', 'module.layers.1.bn3.running_mean', 'module.layers.1.bn3.running_var', 'module.layers.1.bn3.num_batches_tracked', 'module.layers.1.shortcut.0.weight', 'module.layers.1.shortcut.1.weight', 'module.layers.1.shortcut.1.bias', 'module.layers.1.shortcut.1.running_mean', 'module.layers.1.shortcut.1.running_var', 'module.layers.1.shortcut.1.num_batches_tracked', 'module.layers.2.conv1.weight', 'module.layers.2.bn1.weight', 'module.layers.2.bn1.bias', 'module.layers.2.bn1.running_mean', 'module.layers.2.bn1.running_var', 'module.layers.2.bn1.num_batches_tracked', 'module.layers.2.conv2.weight', 'module.layers.2.bn2.weight', 'module.layers.2.bn2.bias', 'module.layers.2.bn2.running_mean', 'module.layers.2.bn2.running_var', 'module.layers.2.bn2.num_batches_tracked', 'module.layers.2.conv3.weight', 'module.layers.2.bn3.weight', 'module.layers.2.bn3.bias', 'module.layers.2.bn3.running_mean', 'module.layers.2.bn3.running_var', 'module.layers.2.bn3.num_batches_tracked', 'module.layers.3.conv1.weight', 'module.layers.3.bn1.weight', 'module.layers.3.bn1.bias', 'module.layers.3.bn1.running_mean', 'module.layers.3.bn1.running_var', 'module.layers.3.bn1.num_batches_tracked', 'module.layers.3.conv2.weight', 'module.layers.3.bn2.weight', 'module.layers.3.bn2.bias', 'module.layers.3.bn2.running_mean', 'module.layers.3.bn2.running_var', 'module.layers.3.bn2.num_batches_tracked', 'module.layers.3.conv3.weight', 'module.layers.3.bn3.weight', 'module.layers.3.bn3.bias', 'module.layers.3.bn3.running_mean', 'module.layers.3.bn3.running_var', 'module.layers.3.bn3.num_batches_tracked', 'module.layers.4.conv1.weight', 'module.layers.4.bn1.weight', 'module.layers.4.bn1.bias', 'module.layers.4.bn1.running_mean', 'module.layers.4.bn1.running_var', 'module.layers.4.bn1.num_batches_tracked', 'module.layers.4.conv2.weight', 'module.layers.4.bn2.weight', 'module.layers.4.bn2.bias', 'module.layers.4.bn2.running_mean', 'module.layers.4.bn2.running_var', 'module.layers.4.bn2.num_batches_tracked', 'module.layers.4.conv3.weight', 'module.layers.4.bn3.weight', 'module.layers.4.bn3.bias', 'module.layers.4.bn3.running_mean', 'module.layers.4.bn3.running_var', 'module.layers.4.bn3.num_batches_tracked', 'module.layers.5.conv1.weight', 'module.layers.5.bn1.weight', 'module.layers.5.bn1.bias', 'module.layers.5.bn1.running_mean', 'module.layers.5.bn1.running_var', 'module.layers.5.bn1.num_batches_tracked', 'module.layers.5.conv2.weight', 'module.layers.5.bn2.weight', 'module.layers.5.bn2.bia ...
# History Contents:
# dict_keys(['train_loss', 'train_acc', 'test_loss', 'test_acc', 'f1', 'precision', 'recall'])
# train_loss: [1.5857905268364245, 1.074495009449132, 0.8518011292533192, 0.750880779817586, 0.6883081130664367]...
# train_acc: [42.52, 61.558, 69.898, 73.68, 76.094]...
# test_loss: [1.3194763553142548, 1.1217692816257476, 0.9633567357063293, 0.7226676163077355, 0.7317531609535217]...
# test_acc: [52.31, 61.69, 68.37, 74.85, 74.71]...
# f1: [0.4196611763993662, 0.520246709700655, 0.6138837472388146, 0.6123487435477454, 0.6980971046261725]...
# precision: [0.41706176084930313, 0.5812253978035459, 0.6127036514677584, 0.6598749978017006, 0.6975077461815631]...
# recall: [0.42519999999999997, 0.5231, 0.61558, 0.6169, 0.6989799999999999]...

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
from datetime import datetime

# Load best model
checkpoint = torch.load(f'{project_dir}/ckpt.pth')
net.load_state_dict(checkpoint['net'])

# Function to compute precision, recall, and confusion matrix
def compute_metrics(loader):
    net.eval()
    all_targets = []
    all_predictions = []

    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            _, predicted = outputs.max(1)
            all_targets.extend(targets.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    precision, recall, _, _ = precision_recall_fscore_support(all_targets, all_predictions, average=None)
    cm = confusion_matrix(all_targets, all_predictions)
    return precision, recall, cm

# Compute precision, recall, and confusion matrix for test data
precision, recall, cm = compute_metrics(testloader)

# Generate a timestamp to uniquely name the plots
timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")

# Plot precision matrix
plt.figure(figsize=(10, 5))
plt.bar(np.arange(len(precision)), precision, color='blue')
plt.xlabel('Class')
plt.ylabel('Precision')
plt.title('Precision per Class')
plt.xticks(np.arange(len(precision)), np.arange(len(precision)))
plt.savefig(f'{project_dir}/precision_matrix_{timestamp}.png')
plt.show()

# Plot recall matrix
plt.figure(figsize=(10, 5))
plt.bar(np.arange(len(recall)), recall, color='orange')
plt.xlabel('Class')
plt.ylabel('Recall')
plt.title('Recall per Class')
plt.xticks(np.arange(len(recall)), np.arange(len(recall)))
plt.savefig(f'{project_dir}/recall_matrix_{timestamp}.png')
plt.show()

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(10))
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.savefig(f'{project_dir}/confusion_matrix_{timestamp}.png')
plt.show()
# Out:
# <ipython-input-9-163aaca3c1bd>:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f'{project_dir}/ckpt.pth')
